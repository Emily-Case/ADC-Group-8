# %%
import pandas as pd
import math
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

df = pd.read_csv("Email-Enron-undirected.csv")

G = nx.from_pandas_edgelist(df, source=df.columns[0], target=df.columns[1])

# %%
nx.is_connected(G)
# Out:
# False

# %%
lcc = list(nx.connected_components(G))[0]

# %% [markdown]
# # Subset of x% nodes with highest degree

# %%
A=G.copy()
x = 0.05
deg_list = sorted(A.degree(), key=lambda x: x[1], reverse=True)
k = math.ceil(x * len(deg_list))
remove = [n for n, d in deg_list[k:]]

A.remove_nodes_from(remove)

# %%
node, degree = max(A.degree(), key=lambda x: x[1])
print("Max degree:", degree)
# Out:
# Max degree: 550

# %% [markdown]
# # K-core Decomposition

# %% [markdown]
# Using network x, we obtain the k-core for every k

# %%
B = G.copy()
cores = []
i = 2

while len(B.nodes()) != 0:
    cores.append(B)
    B = nx.k_core(B, i)
    
    i += 1

print(len(cores[-1]))
# Out:
# 275

# %%
[(i, len(c)) for (i, c) in enumerate(cores)]
# Out:
# [(0, 36692),
#  (1, 25286),
#  (2, 21309),
#  (3, 15386),
#  (4, 11648),
#  (5, 9290),
#  (6, 7061),
#  (7, 5905),
#  (8, 5088),
#  (9, 4513),
#  (10, 4126),
#  (11, 3802),
#  (12, 3530),
#  (13, 3300),
#  (14, 3062),
#  (15, 2873),
#  (16, 2707),
#  (17, 2561),
#  (18, 2416),
#  (19, 2276),
#  (20, 2162),
#  (21, 2055),
#  (22, 1944),
#  (23, 1836),
#  (24, 1731),
#  (25, 1639),
#  (26, 1553),
#  (27, 1469),
#  (28, 1367),
#  (29, 1276),
#  (30, 1170),
#  (31, 1079),
#  (32, 987),
#  (33, 935),
#  (34, 781),
#  (35, 710),
#  (36, 633),
#  (37, 592),
#  (38, 516),
#  (39, 456),
#  (40, 370),
#  (41, 327),
#  (42, 275)]

# %% [markdown]
# We select which one we want to study:

# %%
C = cores[max(range(len(cores)), key=lambda k: k * len(cores[k]))]
print(C)
# Out:
# Graph with 11648 nodes and 138578 edges

# %%
print(nx.is_connected(C))
print(len(list(nx.connected_components(C))))
# Out:
# False
# 15

# %% [markdown]
# We then extract the largest core component

# %%
largest_nodes = max(nx.connected_components(C), key=len)
D = C.subgraph(largest_nodes).copy()
print(D)
print(nx.is_connected(D))
print(nx.is_directed(G))
# Out:
# Graph with 11538 nodes and 138245 edges
# True
# False

# %% [markdown]
# # Network Analysis

# %% [markdown]
# We first get the number of nodes, edges and calculate the density

# %%
n_nodes = D.number_of_nodes()
print(n_nodes)
n_edges = D.number_of_edges()
print(n_edges)
density = nx.density(D)
print(density)
# Out:
# 11538
# 138245
# 0.002077093282800972

# %% [markdown]
# Now we get the degree of each node, plot it and get the average degree

# %%
degrees = [D.degree(n) for n in D.nodes]
avg_degree = sum(degrees)/len(D)
print(avg_degree)
# Out:
# 23.963425203674813

# %%
degree_counts = Counter(degrees)
min_degree, max_degree = min(degree_counts.keys()), max(degree_counts.keys())

#Plot the distribution
plot_x = list(range(min_degree, max_degree + 1))
plot_y = [degree_counts.get(x, 0) for x in plot_x]
plt.xlabel("Degree k")
plt.ylabel("Degree Count")
plt.title("Degree Distribution")
plt.bar(plot_x, plot_y)
plt.show()

# Plot on log–log scale
plt.figure(figsize=(8,6))
plt.loglog(plot_x, plot_y, marker='o', linestyle='none')
plt.xlabel("Degree k")
plt.ylabel("Degree Count")
plt.title("Log–Log Degree Distribution")
plt.grid(True, which="both", ls="--", lw=0.5)
plt.show()

# %% [markdown]
# Now we calculate the centralities and plot them

# %%
degree_centrality = nx.degree_centrality(D)
#print(degree_centrality)

values = list(degree_centrality.values())

plt.figure(figsize=(7,5))
plt.hist(values, bins=30, edgecolor='black')
plt.title("Degree Centrality Distribution")
plt.xlabel("Centrality Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %%
betweenness_centrality = nx.betweenness_centrality(D)
#print(betweenness_centrality)

values = list(betweenness_centrality.values())

plt.figure(figsize=(7,5))
plt.hist(values, bins=30, edgecolor='black')
plt.title("Betweenness Centrality Distribution")
plt.xlabel("Centrality Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %%
closeness_centrality = nx.closeness_centrality(D)
#print(closeness_centrality)

values = list(closeness_centrality.values())

plt.figure(figsize=(7,5))
plt.hist(values, bins=30, edgecolor='black')
plt.title("Closeness Centrality Distribution")
plt.xlabel("Centrality Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 closeness_centrality = nx.closeness_centrality(D)
#       2 #print(closeness_centrality)
#       4 values = list(closeness_centrality.values())
#
# File <class 'networkx.utils.decorators.argmap'> compilation 44:3, in argmap_closeness_centrality_41(G, u, distance, wf_improved, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~\anaconda3\Lib\site-packages\networkx\utils\backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\centrality\closeness.py:124, in closeness_centrality(G, u, distance, wf_improved)
#     122 closeness_dict = {}
#     123 for n in nodes:
# --> 124     sp = path_length(G, n)
#     125     totsp = sum(sp.values())
#     126     len_G = len(G)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 48:3, in argmap_single_source_shortest_path_length_45(G, source, cutoff, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~\anaconda3\Lib\site-packages\networkx\utils\backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py:63, in single_source_shortest_path_length(G, source, cutoff)
#      61     cutoff = float("inf")
#      62 nextlevel = [source]
# ---> 63 return dict(_single_shortest_path_length(G._adj, nextlevel, cutoff))
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py:91, in _single_shortest_path_length(adj, firstlevel, cutoff)
#      89 for v in thislevel:
#      90     for w in adj[v]:
# ---> 91         if w not in seen:
#      92             seen.add(w)
#      93             nextlevel.append(w)
#
# KeyboardInterrupt:

# %%
eigenvector_centrality = nx.eigenvector_centrality(D)
#print(eigenvector_centrality)

values = list(eigenvector_centrality.values())

plt.figure(figsize=(7,5))
plt.hist(values, bins=30, edgecolor='black')
plt.title("Eigenvector Centrality Distribution")
plt.xlabel("Centrality Value")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Now we calculate the paths

# %%
avg_shortest_path = nx.average_shortest_path_length(D)
print(avg_shortest_path)
diameter = nx.diameter(D)
print(diameter)
# Out:
# 3.410414791674733
# 9

# %% [markdown]
# Now we calculate the clustering and plot it

# %%
clustering = nx.clustering(D)
#print(clustering)

values = list(clustering.values())

plt.figure(figsize=(7,5))
plt.hist(values, bins=30, edgecolor='black')
plt.title("Clustering Coefficient Distribution")
plt.xlabel("Clustering Coefficient")
plt.ylabel("Frequency")
plt.grid(alpha=0.3)
plt.show()

avg_clustering = nx.average_clustering(D)
print(avg_clustering)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 clustering = nx.clustering(D)
#       2 #print(clustering)
#       4 values = list(clustering.values())
#
# File <class 'networkx.utils.decorators.argmap'> compilation 73:3, in argmap_clustering_70(G, nodes, weight, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~\anaconda3\Lib\site-packages\networkx\utils\backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\cluster.py:418, in clustering(G, nodes, weight)
#     416     else:
#     417         td_iter = _triangles_and_degree_iter(G, nodes)
# --> 418         clusterc = {v: 0 if t == 0 else t / (d * (d - 1)) for v, d, t, _ in td_iter}
#     419 if nodes in G:
#     420     # Return the value of the sole entry in the dictionary.
#     421     return clusterc[nodes]
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\cluster.py:106, in _triangles_and_degree_iter(G, nodes)
#     104 for v, v_nbrs in nodes_nbrs:
#     105     vs = set(v_nbrs) - {v}
# --> 106     gen_degree = Counter(len(vs & (set(G[w]) - {w})) for w in vs)
#     107     ntriangles = sum(k * val for k, val in gen_degree.items())
#     108     yield (v, len(vs), ntriangles, gen_degree)
#
# File ~\anaconda3\Lib\collections\__init__.py:611, in Counter.__init__(self, iterable, **kwds)
#     600 '''Create a new, empty Counter object.  And if given, count elements
#     601 from an input iterable.  Or, initialize the count from another mapping
#     602 of elements to their counts.
#    (...)
#     608
#     609 '''
#     610 super().__init__()
# --> 611 self.update(iterable, **kwds)
#
# File ~\anaconda3\Lib\collections\__init__.py:703, in Counter.update(self, iterable, **kwds)
#     701             super().update(iterable)
#     702     else:
# --> 703         _count_elements(self, iterable)
#     704 if kwds:
#     705     self.update(kwds)
#
# File ~\anaconda3\Lib\site-packages\networkx\algorithms\cluster.py:106, in <genexpr>(.0)
#     104 for v, v_nbrs in nodes_nbrs:
#     105     vs = set(v_nbrs) - {v}
# --> 106     gen_degree = Counter(len(vs & (set(G[w]) - {w})) for w in vs)
#     107     ntriangles = sum(k * val for k, val in gen_degree.items())
#     108     yield (v, len(vs), ntriangles, gen_degree)
#
# KeyboardInterrupt:

# %% [markdown]
# Now we proceed toward Community Detection

# %%
#MISSING
